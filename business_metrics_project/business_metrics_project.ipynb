# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузите-данные-и-подготовьте-их-к-анализу" data-toc-modified-id="Загрузите-данные-и-подготовьте-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузите данные и подготовьте их к анализу</a></span><ul class="toc-item"><li><span><a href="#Загрузим-данные-о-визитах" data-toc-modified-id="Загрузим-данные-о-визитах-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузим данные о визитах</a></span><ul class="toc-item"><li><span><a href="#Поменяем-название-столбцов-на-корректный" data-toc-modified-id="Поменяем-название-столбцов-на-корректный-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Поменяем название столбцов на корректный</a></span></li><li><span><a href="#Преобразуем-типы-данных" data-toc-modified-id="Преобразуем-типы-данных-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Преобразуем типы данных</a></span></li><li><span><a href="#Проверим-уникальные-значения-в-столбце-region,-device,-channel" data-toc-modified-id="Проверим-уникальные-значения-в-столбце-region,-device,-channel-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Проверим уникальные значения в столбце region, device, channel</a></span></li><li><span><a href="#Проверим-изменения" data-toc-modified-id="Проверим-изменения-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Проверим изменения</a></span></li></ul></li><li><span><a href="#Загрузим-данные-о-заказах" data-toc-modified-id="Загрузим-данные-о-заказах-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузим данные о заказах</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-данные" data-toc-modified-id="Посмотрим-на-данные-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Посмотрим на данные</a></span></li><li><span><a href="#Поменяем-название-столбцов-на-корректный" data-toc-modified-id="Поменяем-название-столбцов-на-корректный-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Поменяем название столбцов на корректный</a></span></li><li><span><a href="#Преобразуем-типы-данных" data-toc-modified-id="Преобразуем-типы-данных-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Преобразуем типы данных</a></span></li><li><span><a href="#Проверим-изменения" data-toc-modified-id="Проверим-изменения-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Проверим изменения</a></span></li></ul></li><li><span><a href="#Загрузим-данные-о-расходах" data-toc-modified-id="Загрузим-данные-о-расходах-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Загрузим данные о расходах</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-данные" data-toc-modified-id="Посмотрим-на-данные-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Посмотрим на данные</a></span></li><li><span><a href="#Изменим-названия-столбцов" data-toc-modified-id="Изменим-названия-столбцов-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Изменим названия столбцов</a></span></li><li><span><a href="#Преобразуем-тип-данных-в-столбце-с-датой" data-toc-modified-id="Преобразуем-тип-данных-в-столбце-с-датой-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Преобразуем тип данных в столбце с датой</a></span></li><li><span><a href="#Проверим-уникальные-значения-в-столбце-channel" data-toc-modified-id="Проверим-уникальные-значения-в-столбце-channel-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Проверим уникальные значения в столбце channel</a></span></li><li><span><a href="#Проверим-изменения" data-toc-modified-id="Проверим-изменения-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Проверим изменения</a></span></li></ul></li></ul></li><li><span><a href="#Создадим-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Создадим-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Создадим функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Составим-профили-пользователей.-Определим-минимальную-и-максимальную-даты-привлечения-пользователей." data-toc-modified-id="Составим-профили-пользователей.-Определим-минимальную-и-максимальную-даты-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.</a></span><ul class="toc-item"><li><span><a href="#Составим-профили-пользователей,-вызвав-функцию-get_profiles" data-toc-modified-id="Составим-профили-пользователей,-вызвав-функцию-get_profiles-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Составим профили пользователей, вызвав функцию get_profiles</a></span></li><li><span><a href="#Зададим-минимальную-и-максимальную-дату-привлечения-пользователей" data-toc-modified-id="Зададим-минимальную-и-максимальную-дату-привлечения-пользователей-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Зададим минимальную и максимальную дату привлечения пользователей</a></span></li></ul></li><li><span><a href="#Высяним-из-какой-страные-пользователи-приходят-в-приложение,-а-так-же-на-какую-страну-приходится-больше-всего-платящих-пользователей" data-toc-modified-id="Высяним-из-какой-страные-пользователи-приходят-в-приложение,-а-так-же-на-какую-страну-приходится-больше-всего-платящих-пользователей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Высяним из какой страные пользователи приходят в приложение, а так же на какую страну приходится больше всего платящих пользователей</a></span><ul class="toc-item"><li><span><a href="#Построим-график,-отображающий-динамику-привлечения-новых-пользователей-по-каждому-из-регионов." data-toc-modified-id="Построим-график,-отображающий-динамику-привлечения-новых-пользователей-по-каждому-из-регионов.-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Построим график, отображающий динамику привлечения новых пользователей по каждому из регионов.</a></span></li></ul></li><li><span><a href="#Узнаем-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи." data-toc-modified-id="Узнаем-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Узнаем какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.</a></span></li><li><span><a href="#Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей." data-toc-modified-id="Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.</a></span><ul class="toc-item"><li><span><a href="#Построим-график,-отображающий-динамику-привлечения-новых-пользователей-по-каждому-из-регионов." data-toc-modified-id="Построим-график,-отображающий-динамику-привлечения-новых-пользователей-по-каждому-из-регионов.-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Построим график, отображающий динамику привлечения новых пользователей по каждому из регионов.</a></span></li></ul></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-общую-сумму-расходов-на-маркетинг" data-toc-modified-id="Посчитаем-общую-сумму-расходов-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посчитаем общую сумму расходов на маркетинг</a></span></li><li><span><a href="#Посчитаем-траты-на-каждый-рекламный-источник,-переведем-в-проценты." data-toc-modified-id="Посчитаем-траты-на-каждый-рекламный-источник,-переведем-в-проценты.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Посчитаем траты на каждый рекламный источник, переведем в проценты.</a></span></li><li><span><a href="#Построим-графики-динамики-изменения-расходов-во-времения-по-каждому-источнику." data-toc-modified-id="Построим-графики-динамики-изменения-расходов-во-времения-по-каждому-источнику.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Построим графики динамики изменения расходов во времения по каждому источнику.</a></span><ul class="toc-item"><li><span><a href="#Добавляем-месяца" data-toc-modified-id="Добавляем-месяца-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Добавляем месяца</a></span></li><li><span><a href="#Добавляем-недели" data-toc-modified-id="Добавляем-недели-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Добавляем недели</a></span></li><li><span><a href="#Создадим-сводные-таблицы-по-месяца-и-неделям" data-toc-modified-id="Создадим-сводные-таблицы-по-месяца-и-неделям-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Создадим сводные таблицы по месяца и неделям</a></span></li><li><span><a href="#Строим-графики" data-toc-modified-id="Строим-графики-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Строим графики</a></span></li></ul></li><li><span><a href="#Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника." data-toc-modified-id="Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.</a></span></li><li><span><a href="#Оцените-окупаемость-рекламы" data-toc-modified-id="Оцените-окупаемость-рекламы-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Оцените окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Посмотрим-на-конверсию-пользователей-и-динамику-ее-изменения-по-устройствам." data-toc-modified-id="Посмотрим-на-конверсию-пользователей-и-динамику-ее-изменения-по-устройствам.-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Посмотрим на конверсию пользователей и динамику ее изменения по устройствам.</a></span></li><li><span><a href="#Посмотрим-на-удержание-пользователей-и-динамику-ее-изменения-по-устройствам." data-toc-modified-id="Посмотрим-на-удержание-пользователей-и-динамику-ее-изменения-по-устройствам.-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>Посмотрим на удержание пользователей и динамику ее изменения по устройствам.</a></span></li><li><span><a href="#Cмотрим-окупаемость-с-разбивкой-по-устройствам" data-toc-modified-id="Cмотрим-окупаемость-с-разбивкой-по-устройствам-4.5.4"><span class="toc-item-num">4.5.4&nbsp;&nbsp;</span>Cмотрим окупаемость с разбивкой по устройствам</a></span></li><li><span><a href="#Cмотрим-окупаемость-с-разбивкой-по-странам" data-toc-modified-id="Cмотрим-окупаемость-с-разбивкой-по-странам-4.5.5"><span class="toc-item-num">4.5.5&nbsp;&nbsp;</span>Cмотрим окупаемость с разбивкой по странам</a></span></li><li><span><a href="#Смотрим-окупаемость-по-рекламным-каналам" data-toc-modified-id="Смотрим-окупаемость-по-рекламным-каналам-4.5.6"><span class="toc-item-num">4.5.6&nbsp;&nbsp;</span>Смотрим окупаемость по рекламным каналам</a></span></li><li><span><a href="#Посмотрим-на-конверсию-пользователей-и-динамику-ее-изменения-по-рекламным-каналам." data-toc-modified-id="Посмотрим-на-конверсию-пользователей-и-динамику-ее-изменения-по-рекламным-каналам.-4.5.7"><span class="toc-item-num">4.5.7&nbsp;&nbsp;</span>Посмотрим на конверсию пользователей и динамику ее изменения по рекламным каналам.</a></span></li><li><span><a href="#Посмотрим-на-удержание-пользователей-и-динамику-ее-изменения-по-рекламным-каналам." data-toc-modified-id="Посмотрим-на-удержание-пользователей-и-динамику-ее-изменения-по-рекламным-каналам.-4.5.8"><span class="toc-item-num">4.5.8&nbsp;&nbsp;</span>Посмотрим на удержание пользователей и динамику ее изменения по рекламным каналам.</a></span></li><li><span><a href="#Посмотрим-на-конверсию-пользователей-и-динамику-ее-изменения-по-устройствам." data-toc-modified-id="Посмотрим-на-конверсию-пользователей-и-динамику-ее-изменения-по-устройствам.-4.5.9"><span class="toc-item-num">4.5.9&nbsp;&nbsp;</span>Посмотрим на конверсию пользователей и динамику ее изменения по устройствам.</a></span></li><li><span><a href="#Посмотрим-на-удержание-пользователей-и-динамику-ее-изменения-по-устройствам." data-toc-modified-id="Посмотрим-на-удержание-пользователей-и-динамику-ее-изменения-по-устройствам.-4.5.10"><span class="toc-item-num">4.5.10&nbsp;&nbsp;</span>Посмотрим на удержание пользователей и динамику ее изменения по устройствам.</a></span></li><li><span><a href="#Посмотрим-на-конверсию-пользователей-и-динамику-ее-изменения-по-регионам." data-toc-modified-id="Посмотрим-на-конверсию-пользователей-и-динамику-ее-изменения-по-регионам.-4.5.11"><span class="toc-item-num">4.5.11&nbsp;&nbsp;</span>Посмотрим на конверсию пользователей и динамику ее изменения по регионам.</a></span></li><li><span><a href="#Посмотрим-на-удержание-пользователей-и-динамику-ее-изменения-по-регионам." data-toc-modified-id="Посмотрим-на-удержание-пользователей-и-динамику-ее-изменения-по-регионам.-4.5.12"><span class="toc-item-num">4.5.12&nbsp;&nbsp;</span>Посмотрим на удержание пользователей и динамику ее изменения по регионам.</a></span></li></ul></li><li><span><a href="#Проверим-с-какого-региона-приходят-пользователи-у-проблемных-каналов" data-toc-modified-id="Проверим-с-какого-региона-приходят-пользователи-у-проблемных-каналов-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Проверим с какого региона приходят пользователи у проблемных каналов</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Загрузите данные и подготовьте их к анализу

# %% [markdown]
# # Цель исследования

# %% [markdown]
# *Приложение Procrastinate Pro+ вкладывает огромные вложения в рекламу, но последние несколько месяцев компания терпит убытки.*
#
# *Проверим данные, посчитаем метрики и разберемся в причинах убытка. Сформулируем рекомендации по улучшению плана маркетинга.*
#
# *У нас есть данные о пользователях, привлеченный с 1 мая по 27 октября 2019 года.*

# %% [markdown]
# *Структура visits:*
# - *User Id — уникальный идентификатор пользователя*
# - *Region — страна пользователя*
# - *Device — тип устройства пользователя*
# - *Channel — идентификатор источника перехода*
# - *Session Start — дата и время начала сессии*
# - *Session End — дата и время окончания сессии*

# %% [markdown]
# *Структура orders:*
# - *User Id — уникальный идентификатор пользователя*
# - *Event Dt — дата и время покупки*
# - *Revenue — сумма заказа*

# %% [markdown]
# *Структура costs:*
# - *dt — дата проведения рекламной кампании*
# - *Channel — идентификатор рекламного источника*
# - *costs — расходы на эту кампанию*

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns
import requests
# %matplotlib inline

# %% [markdown]
# ### Загрузим данные о визитах

# %%
events = None

try:
    visits = pd.read_csv('/Users/nastinpupochek/Downloads/visits_info.csv', sep=',')
except: 
    spreadsheet_id = '10fQYFQf661gO5Cg0DRAG2xUPhzZMcRWJHRYwvvQDkm0'
    file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
    r = requests.get(file_name)
    game_df = pd.read_csv(BytesIO(r.content), sep=',')

# %%
def df_info(df):
    display(df.head())
    print(f'Количество строк: {df.shape[0]}')
    print(f'\nКоличество пропущенных значений: \n{df.isna().sum()}')
    print(f'\nТипы данных в столбцах: \n{df.dtypes}')
    print(f'\nКоличество дубликатов: \n{df.duplicated().sum()}')
    return df_info
df_info(visits)
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
# Количество строк: 309901
#
# Количество пропущенных значений:
# User Id          0
# Region           0
# Device           0
# Channel          0
# Session Start    0
# Session End      0
# dtype: int64
#
# Типы данных в столбцах:
# User Id           int64
# Region           object
# Device           object
# Channel          object
# Session Start    object
# Session End      object
# dtype: object
#
# ...

# %% [markdown]
# #### Поменяем название столбцов на корректный

# %%
visits.columns = visits.columns.str.lower()

# %%
visits = visits.rename(columns={'user id': 'user_id',
                                'session start': 'session_start', 
                                'session end': 'session_end'})

# %% [markdown]
# #### Преобразуем типы данных

# %%
visits.session_start = pd.to_datetime(visits.session_start)
visits.session_end = pd.to_datetime(visits.session_end)

# %% [markdown]
# #### Проверим уникальные значения в столбце region, device, channel

# %%
visits.region.unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits.device.unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits.channel.unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# #### Проверим изменения

# %%
df_info(visits)
# Out:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           session_end
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# 4 2019-05-01 03:57:40
# Количество строк: 309901
#
# Количество пропущенных значений:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64
#
# Типы данных в столбцах:
# user_id                   int64
# region                   object
# device                   object
# channel                  object
# session_start    datetime64[ns]
# ...

# %% [markdown]
# ### Загрузим данные о заказах

# %%
try:
    orders = pd.read_csv('/Users/nastinpupochek/Downloads/orders_info.csv', sep=',')
except: 
    spreadsheet_id = '1rTaFss6NIdKryknA5Sjr6InEfVmvnbgdUTBXEzBRtuk'
    file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
    r = requests.get(file_name)
    game_df = pd.read_csv(BytesIO(r.content), sep=',')

# %% [markdown]
# #### Посмотрим на данные

# %%
df_info(orders)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# Количество строк: 40212
#
# Количество пропущенных значений:
# User Id     0
# Event Dt    0
# Revenue     0
# dtype: int64
#
# Типы данных в столбцах:
# User Id       int64
# Event Dt     object
# Revenue     float64
# dtype: object
#
# Количество дубликатов:
# 0
# <function __main__.df_info(df)>

# %% [markdown]
# #### Поменяем название столбцов на корректный

# %%
orders.columns = orders.columns.str.lower()

# %%
orders = orders.rename(columns={'user id': 'user_id', 
                                'event dt': 'event_dt'})

# %% [markdown]
# #### Преобразуем типы данных

# %%
orders.event_dt = pd.to_datetime(orders.event_dt)

# %% [markdown]
# #### Проверим изменения

# %%
df_info(orders)
# Out:
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
# Количество строк: 40212
#
# Количество пропущенных значений:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64
#
# Типы данных в столбцах:
# user_id              int64
# event_dt    datetime64[ns]
# revenue            float64
# dtype: object
#
# Количество дубликатов:
# 0
# <function __main__.df_info(df)>

# %% [markdown]
# ### Загрузим данные о расходах

# %%
try:
    costs = pd.read_csv('/Users/nastinpupochek/Downloads/costs_info.csv', sep=',')
except: 
    spreadsheet_id = '1wOoSNTbCVH5IaRB2tGhuEDcSopg78OyzmYZoLOz_3PI'
    file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
    r = requests.get(file_name)
    game_df = pd.read_csv(BytesIO(r.content), sep=',')

# %% [markdown]
# #### Посмотрим на данные

# %%
df_info(costs)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# Количество строк: 1800
#
# Количество пропущенных значений:
# dt         0
# Channel    0
# costs      0
# dtype: int64
#
# Типы данных в столбцах:
# dt          object
# Channel     object
# costs      float64
# dtype: object
#
# Количество дубликатов:
# 0
# <function __main__.df_info(df)>

# %% [markdown]
# #### Изменим названия столбцов

# %%
costs.columns = costs.columns.str.lower()

# %% [markdown]
# #### Преобразуем тип данных в столбце с датой

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# #### Проверим уникальные значения в столбце channel

# %%
costs.channel.unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# #### Проверим изменения

# %%
df_info(costs)
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# Количество строк: 1800
#
# Количество пропущенных значений:
# dt         0
# channel    0
# costs      0
# dtype: int64
#
# Типы данных в столбцах:
# dt          object
# channel     object
# costs      float64
# dtype: object
#
# Количество дубликатов:
# 0
# <function __main__.df_info(df)>

# %% [markdown]
# **Вывод**
#
# *В данных были обнаружены некорректно записаны наименование столбцов, а именно названия столбцов с заглавной буквы, и пробелы между словами. Так же поменяли тип данных в столбцах с датой, для дайльнейшего исследования*

# %% [markdown]
# ## Создадим функции для расчёта и анализа LTV, ROI, удержания и конверсии.

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.

# %% [markdown]
# #### Составим профили пользователей, вызвав функцию get_profiles

# %%
profiles = get_profiles(visits, orders, events, costs)

# %%
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# #### Зададим минимальную и максимальную дату привлечения пользователей

# %%
min_date = profiles.dt.min()
print('Минимальная дата привлечения {}'.format(min_date))
# Out:
# Минимальная дата привлечения 2019-05-01

# %%
max_date = profiles.dt.max()
print('Максимальная дата привлечения {}'.format(max_date))
# Out:
# Максимальная дата привлечения 2019-10-27

# %% [markdown]
# ### Высяним из какой страные пользователи приходят в приложение, а так же на какую страну приходится больше всего платящих пользователей

# %%
profiles.groupby('region') \
    .agg({'user_id': 'nunique', 'payer': 'mean'}) \
    .sort_values(by='payer', ascending=False)
# Out:
#                user_id     payer
# region
# United States   100002  0.069019
# Germany          14981  0.041119
# UK               17575  0.039829
# France           17450  0.037994

# %% [markdown]
# #### Построим график, отображающий динамику привлечения новых пользователей по каждому из регионов.

# %%
profiles.pivot_table(
    index='dt',  # даты первых посещений
    columns='region',  # источники переходов
    values='user_id',  # ID пользователей
    aggfunc='nunique'  # подсчёт уникальных значений
).plot(figsize=(15, 5), grid=True)

plt.show()

# %% [markdown]
# **Вывод**
#
# *По данным видим, что больше всего клиентов приходят из региона USA, что хорошо видно на графике динамики привлечения клиентов, и на этот же регион приходится большая доля платящих клиентов. Примерно одинаковое количество клиентов приходят из региона UK и France, как и их доля платящих клиентов. И на последнем месте трафик из Germany, но доля платящих клиентов выше чем в UK и France, и очень близка к доле USA. Получается что клиентов из Germany приходит меньше всего, но доля оплаты с этого региона высокая.*

# %% [markdown]
# ### Узнаем какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.

# %%
profiles.groupby('device') \
        .agg({'user_id': 'nunique', 'payer': 'mean'}) \
        .sort_values(by='payer', ascending=False)
# Out:
#          user_id     payer
# device
# Mac        30042  0.063644
# iPhone     54479  0.062079
# Android    35032  0.058518
# PC         30455  0.050468

# %% [markdown]
# **Вывод**
#
# *На мобильных устройствах клиентов больше всего, а именно на Iphone, так же как и доля платящих клиентов. Количество клиентов на PC и Mac практически одинаковое, но доля покупок на Mac платформе выше.*

# %% [markdown]
# ### Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.

# %%
profiles.groupby('channel') \
    .agg({'user_id': 'nunique', 'payer': 'mean'}) \
    .sort_values(by='payer', ascending=False)
# Out:
#                     user_id     payer
# channel
# FaceBoom              29144  0.122049
# AdNonSense             3880  0.113402
# lambdaMediaAds         2149  0.104700
# TipTop                19561  0.096007
# RocketSuperAds         4448  0.079137
# WahooNetBanner         8553  0.052964
# YRabbit                4312  0.038265
# MediaTornado           4364  0.035747
# LeapBob                8553  0.030633
# OppleCreativeMedia     8605  0.027077
# organic               56439  0.020553

# %% [markdown]
# #### Построим график, отображающий динамику привлечения новых пользователей по каждому из регионов.

# %%
channel_pivot = profiles.pivot_table(
    index='dt',  # даты первых посещений
    columns='channel',  # источники переходов
    values='user_id',  # ID пользователей
    aggfunc='nunique'  # подсчёт уникальных значений
).plot(figsize=(15, 5), grid=True)

plt.show()

# %% [markdown]
# **Вывод**
#
# *Больше всего клиентов приходят с органического канала, у которого замечается резкие скачки по количеству пользователей, пик приходится на 5-6 месяц. Каналы Face Boom и Tip Top приносят стабильное количество клиентов, но Face Boom заметно больше и доля покупок у этого канала выше. Затем выделяются три канала Opple Creative Media, Leap Bob, Wahoo Net Banner, где у Wahoo Net Banner доля покупок выше. Так же стабильно приносят клиентов каналы Rocket Super Ads, Media Tornado, YRabbit, при чем доля покупок у Rocket Super Ads практически догоняет канал Tip Top и при это количество клиентов в 4 раза меньше. Меньше всего приносят каналы Ad Non Sense и lambda Media Ads, так же как и доля покупок самая низкая среди каналов.*

# %% [markdown]
# ## Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# ### Посчитаем общую сумму расходов на маркетинг

# %%
total_costs = costs.costs.sum().astype(int)
print('Общая сумма расходов на маркетинг: {}'.format(total_costs))
# Out:
# Общая сумма расходов на маркетинг: 105497

# %% [markdown]
# ### Посчитаем траты на каждый рекламный источник, переведем в проценты.

# %%
costs_channel = costs.groupby('channel').agg({'costs': 'sum'}) \
    .reset_index() \
    .sort_values(by='costs', ascending=False)

# %%
costs_channel['perc'] = (costs_channel.costs / total_costs * 100).round()
costs_channel
# Out:
#               channel     costs  perc
# 6              TipTop  54751.30  52.0
# 1            FaceBoom  32445.60  31.0
# 7      WahooNetBanner   5151.00   5.0
# 0          AdNonSense   3911.25   4.0
# 4  OppleCreativeMedia   2151.25   2.0
# 5      RocketSuperAds   1833.00   2.0
# 2             LeapBob   1797.60   2.0
# 9      lambdaMediaAds   1557.60   1.0
# 3        MediaTornado    954.48   1.0
# 8             YRabbit    944.22   1.0

# %% [markdown]
# **Вывод**
#
# *После подчета распределения бюджета, видим, что 2 канала из всех, тратится 83%, а именно 52% на Tip Top и 31% на Face Boom*

# %% [markdown]
# ### Построим графики динамики изменения расходов во времения по каждому источнику.

# %% [markdown]
# #### Добавляем месяца

# %%
costs['month'] = costs['dt'].astype('datetime64[M]')

# %% [markdown]
# #### Добавляем недели

# %%
costs['week'] =costs['dt'].astype('datetime64[W]')

# %%
display(costs.head())
# Out:
#            dt   channel  costs      month       week
# 0  2019-05-01  FaceBoom  113.3 2019-05-01 2019-04-25
# 1  2019-05-02  FaceBoom   78.1 2019-05-01 2019-05-02
# 2  2019-05-03  FaceBoom   85.8 2019-05-01 2019-05-02
# 3  2019-05-04  FaceBoom  136.4 2019-05-01 2019-05-02
# 4  2019-05-05  FaceBoom  122.1 2019-05-01 2019-05-02

# %% [markdown]
# #### Создадим сводные таблицы по месяца и неделям

# %%
month_costs = costs.pivot_table(index='month', columns='channel', values='costs', aggfunc='sum').reset_index()

# %%
week_costs = costs.pivot_table(index='week', columns='channel', values='costs', aggfunc='sum').reset_index()

# %% [markdown]
# #### Строим графики

# %%
plt.figure(figsize=(15, 7))
ax1 = plt.subplot(1, 2, 1)
month_costs.plot(grid=True, ax=ax1)
plt.legend()
plt.xlabel('Месяцы')
plt.title('Динамика расходов по месяцам')

ax2 = plt.subplot(1, 2, 2, sharey=ax1)
week_costs.plot(grid=True, ax=ax2)
plt.xlabel('Недели')
plt.title('Недельная динамика расходов')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод**
#
# *Огромные затраты на рекламу приходятся на канал Tip Top, следом на Face Boom, пик затрат пришелся на 4 месяц и 21-22 неделю у Tip Top и 3 месяц и 21-22 неделю у Face Boom. На остальные каналы тратится в разы меньше рекламы, самые малозатратные каналы это YRabbit и MediaTornado. Так же заметно как в первый месяц на канал Ad Non Sense потратили сразу практически максимальную сумму,а после затраты резко уменьшились.*

# %% [markdown]
# ### Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
profiles = get_profiles(visits, orders, events, costs)

# %%
cac_tb = profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean')
cac_tb.head()
# Out:
# channel     AdNonSense  FaceBoom  LeapBob  MediaTornado  OppleCreativeMedia  \
# dt
# 2019-05-01    1.050000  1.089423  0.21000      0.240000            0.236111
# 2019-05-02    0.962500  1.084722  0.18375      0.229091            0.265625
# 2019-05-03    1.050000  1.128947  0.21000      0.232000            0.239583
# 2019-05-04    1.008824  1.108943  0.19950      0.212727            0.250000
# 2019-05-05    1.020833  1.080531  0.20087      0.230000            0.250000
#
# channel     RocketSuperAds    TipTop  WahooNetBanner   YRabbit  \
# dt
# 2019-05-01        0.540000  0.975610        0.568421  0.289286
# 2019-05-02        0.565500  1.000000        0.514286  0.253846
# 2019-05-03        0.528387  1.049180        0.600000  0.310345
# 2019-05-04        0.531818  0.972222        0.540000  0.294340
# 2019-05-05        0.561122  1.012987        0.600000  0.290909
#
# channel     lambdaMediaAds  organic
# dt
# 2019-05-01        0.765217      0.0
# 2019-05-02        0.730435      0.0
# ...

# %%
cac_tb.plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# **Вывод**
#
# *С канала Tip Top самые дорогие клиенты, и с каждым месяцем затраты на канал увеличиваются. Стабильная стоимость клиентов с канала Face Boom. Стоимость пользователя с каналов Ad Non Sense и Lambda Media Ads уходит примерно одинаковое количество, при чем на обоиз каналах заметны как резкое снижение стоимости, так и в обратную сторону. Видно снижение стоимости у канала Rocket Super Ads*

# %% [markdown]
# ### Оцените окупаемость рекламы

# %% [markdown]
# #### Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %% [markdown]
# *Зададим момент анализа и горизонт анализа по бизнес-плану*

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# *Исключим из данных органический канал, так как мы не тратим на его привлечения бюджет*

# %%
profiles = profiles[profiles['channel'] != 'organic']

# %% [markdown]
# *Считаем LTV и ROI*

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Вывод**
#
# *Ltv стабильно растет, значит качество пользователей хорошее. Затраты на привлечения плавно растут, начиная с 5 месяца. При это реклама все еще не окупилась, ROI на 14 день составляем всего лишь 80%. Разберем в чем причина.*

# %% [markdown]
# #### Посмотрим на конверсию пользователей и динамику ее изменения по устройствам.

# %%
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Вывод**
#
# *Заметна низкая конверсия среди PC юзеров, среди других устройст конверсия практически одинаковая.*

# %% [markdown]
# #### Посмотрим на удержание пользователей и динамику ее изменения по устройствам.

# %%
dimensions = ['device']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Вывод**
#
# *При низкой конверсии PC устройств, удержание у них выше других. И в целом динамика удержания зеркальна конверсии. И при этом у всех устройств на 14 день удержание низкое*

# %% [markdown]
# #### Cмотрим окупаемость с разбивкой по устройствам

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=16
)

# %% [markdown]
# **Вывод**
#
# *При хорошей конверсии на iphone и mac, эти устройства не окупаются, и на 14 день roi не достигает даже 80%, Andriod так же не окупается, но roi выше чем у iphone и mac. При том PC устройства окупаются на 7 день. И при таких показателях окупаемости, динамика стоимость привлеченного клиента на устройствах PC и Mac очень высокая, по сравнению с Pc, за счет чего и затраты окупаются.*

# %% [markdown]
# #### Cмотрим окупаемость с разбивкой по странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=16
)

# %% [markdown]
# **Вывод**
#
# *При очень высокой динамики стоимости пользователей у региона USA, затраты на этих пользователей не окупаются совсем. В то время как пользоватлеи с других регионов окупаются уже на 4-5 день, и динамика затрат у этих регионов низкая и стабильная.*

# %% [markdown]
# #### Смотрим окупаемость по рекламным каналам

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=31
)

# %% [markdown]
# **Вывод**
#
# *Каналы Tip Top, Face Boom, AdNon Sense не окупаются совсем и затраты на канал Tip Top и Face Boom самые большие. Посмотрим на конверсию и удержание по этим каналам*

# %% [markdown]
# #### Посмотрим на конверсию пользователей и динамику ее изменения по рекламным каналам.

# %%
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# *Конверсия по проблемным каналам впорядке, а вот конверсии других каналов не так хороша. Но стоит выделить канал Labda Media Ads который при низких затратах и быстрой окупаемости, имеет неплохую конверсию, которая выше самого дорого канала*

# %% [markdown]
# #### Посмотрим на удержание пользователей и динамику ее изменения по рекламным каналам.

# %%
dimensions = ['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# *Удержания по каналам AdNonSense и FaceBoom меньше более 30%. Перед заключением о проблемном трафике с дорогих каналаов, посмотри на конверсию и удержания по устройствам и регионам*

# %% [markdown]
# #### Посмотрим на конверсию пользователей и динамику ее изменения по устройствам.

# %%
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Вывод**
#
# *Заметна низкая конверсия среди PC пользователей, среди других устройст конверсия практически одинаковая.*

# %% [markdown]
# #### Посмотрим на удержание пользователей и динамику ее изменения по устройствам.

# %%
dimensions = ['device']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Вывод**
#
# *При низкой конверсии PC устройств, удержание у них выше других. И в целом динамика удержания зеркальна конверсии. И при этом у всех устройств на 14 день удержание низкое*

# %% [markdown]
# #### Посмотрим на конверсию пользователей и динамику ее изменения по регионам.

# %%
dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# *Высоки показатель конверсии у пользователей в регионе USA, в остальных регионах показатель примерно на одном уровне*

# %% [markdown]
# #### Посмотрим на удержание пользователей и динамику ее изменения по регионам.

# %%
dimensions = ['region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# *Но при этом процент удержания в регионе USA ниже остальных примерно на 10%*

# %% [markdown]
# **Вывод**
#
# *Самые большие траты на рекламные каналы пришлись на TipTop и Face Boom. Клиенты с Face Boom
# удерживаются примерно на 30% хуже остальных клиентов. А пользователи с TipTop, при самых больших затратах, показывают не высокую конверсию в сравнении с другими пользователями, на которых было потрачено меньше средств.*

# %% [markdown]
# ### Проверим с какого региона приходят пользователи у проблемных каналов

# %%
profiles.pivot_table(index='region', columns='channel', values='user_id', aggfunc='nunique' ) \
    .reset_index() \
    .fillna(0)
# Out:
# channel         region  AdNonSense  FaceBoom  LeapBob  MediaTornado  \
# 0               France      1366.0       0.0   2988.0           0.0
# 1              Germany      1219.0       0.0   2519.0           0.0
# 2                   UK      1295.0       0.0   3046.0           0.0
# 3        United States         0.0   29144.0      0.0        4364.0
#
# channel  OppleCreativeMedia  RocketSuperAds   TipTop  WahooNetBanner  YRabbit  \
# 0                    2991.0             0.0      0.0          2971.0      0.0
# 1                    2562.0             0.0      0.0          2579.0      0.0
# 2                    3052.0             0.0      0.0          3003.0      0.0
# 3                       0.0          4448.0  19561.0             0.0   4312.0
#
# channel  lambdaMediaAds
# 0                 742.0
# 1                 649.0
# 2                 758.0
# 3                   0.0

# %% [markdown]
# *Весь дорогой трафик приходит с региона USA, в котором при высокой конверсии, низкое удерживание клиентов*

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# *В ходе исселодвания мы обнаружили, что присутствуют три канала которые совсем не окупаются - это Tip Top, Face Boom и Ad Non Sense. И на эти каналы было потрачено больше всего бюджета, Ad Non Sense на 4-5 месте по тратам. А на каналы с быстрой и высокой окупаемостью было потрачено намного меньше бюджета. Так же было обнаружено, что пользователи с региона USA имею высокую конверсию, но при это низкий показатель удержания. После разбивки пользователей по каналам и регионам, выяснили что рекламные каналы, которые не окупаются, приходят с региона USA, а именно Face Boom и Tip Top.*

# %% [markdown]
# *На основании исследования можно сформировать рекомендации:*
# - *Пересмотреть выбор рекламного канала в регионе USA*
# - *Распределить бюджет на рекламные каналы равномерно*
# - *Стоит выделить бюджет на рекламные каналы в регионы кроме USA, так как другие регионы отмечаются хорошим показателем удержания, платящих пользователей и у которых есть каналы с хорошими метриками, один из самых заметных - Labda Media Ads*
# - *Так же стоит проверить сайт, агрегаторы оплаты и тп на PC устройствах, пользователи которых отмечаются низкой конверсией*
# - *Продумать стратегии по удержанию клиентов*
